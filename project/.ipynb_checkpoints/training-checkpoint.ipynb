# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
df = pd.read_csv('training.csv' , header=0)

# %%
df.head()
# Out:
#    DVM ID                        Account Name Billing State/Province  \
# 0   90099                 Cape Veterinary, PC                  Maine
# 1   82002        Maple Lane Veterinary Clinic               Virginia
# 2   93464  Coastal Equine Veterinary Services               Virginia
# 3  112542      Animal Wellness Concepts, Inc.                Florida
# 4  113028   At Home Veterinary Services, PLLC               Michigan
#
#   Account Owner            Lead Source Additional Providers Go-Live Date  \
# 0   Sarah Mills              Cold Call   No Online Pharmacy       6/3/15
# 1   Brian Kelly                    PST                  NaN      5/28/15
# 2   Brian Kelly  Manufacturer Referral    Webster/VetSource      5/20/15
# 3  Wendy Bouton               VFC List          MWI/ProxyRx      5/16/15
# 4   Sarah Mills   Practice Web Inquiry                  NaN      5/16/15
#
#   Training Done  ttt  inbound  competitive bracket  revenue
# 0        6/9/15    6        0            1   0-500        0
# 1        6/8/15   11        0            0   0-500        0
# 2       5/21/15    1        0            1   0-500        0
# 3       5/15/15    0        0            1   0-500        0
# 4       5/20/15    4        1            0   0-500        0

# %%
X = df[['ttt','inbound','competitive']]
y = df['revenue']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                revenue   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     7.643
# Date:                Tue, 09 Jun 2015   Prob (F-statistic):           5.70e-05
# Time:                        20:49:51   Log-Likelihood:                -3455.1
# No. Observations:                 376   AIC:                             6918.
# Df Residuals:                     372   BIC:                             6934.
# Df Model:                           3
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# const        1293.8341    228.362      5.666      0.000       844.791  1742.877
# ttt            -8.4875      4.548     -1.866      0.063       -17.431     0.456
# inbound        -0.1309    258.210     -0.001      1.000      -507.865   507.604
# competitive  1448.1540    323.454      4.477      0.000       812.126  2084.182
# ==============================================================================
# Omnibus:                      402.760   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            23180.935
# Skew:                           4.608   Prob(JB):                         0.00
# Kurtosis:                      40.346   Cond. No.                         86.6
# ==============================================================================
# """
