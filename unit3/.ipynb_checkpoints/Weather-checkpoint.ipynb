# %%
import requests
import sqlite3 as lite
import time
from dateutil.parser import parse 
import collections
import pandas as pd
import datetime

# %%
cities = { "Atlanta": '33.762909,-84.422675',
            "Austin": '30.303936,-97.754355',
            "Boston": '42.331960,-71.020173',
            "Chicago": '41.837551,-87.681844',
            "Cleveland": '41.478462,-81.679435'
        }

# %%
con = lite.connect('weather.db')
cur = con.cursor()
with con:
    cur.execute('DROP TABLE weather')
    cur.execute('CREATE TABLE weather (city TEXT, time INT, temp NUMERIC )')

# %%
r = requests.get('https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/42.331960,-71.020173,1428881556')
r.json()
# Out:
# {u'currently': {u'apparentTemperature': 61.8,
#   u'cloudCover': 0.27,
#   u'dewPoint': 34.96,
#   u'humidity': 0.37,
#   u'icon': u'partly-cloudy-night',
#   u'precipIntensity': 0,
#   u'precipProbability': 0,
#   u'pressure': 1023.36,
#   u'summary': u'Partly Cloudy',
#   u'temperature': 61.8,
#   u'time': 1428881556,
#   u'visibility': 10,
#   u'windBearing': 197,
#   u'windSpeed': 7.97},
#  u'daily': {u'data': [{u'apparentTemperatureMax': 66.14,
#     u'apparentTemperatureMaxTime': 1428868800,
#     u'apparentTemperatureMin': 33.86,
#     u'apparentTemperatureMinTime': 1428825600,
#     u'cloudCover': 0.08,
#     u'dewPoint': 30.09,
#     u'humidity': 0.45,
#     u'icon': u'partly-cloudy-night',
#     u'moonPhase': 0.77,
#     u'precipIntensity': 0,
#     u'precipIntensityMax': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.91,
#     u'summary': u'Partly cloudy starting in the evening.',
#     u'sunriseTime': 1428833373,
#     u'sunsetTime': 1428880946,
#     u'temperatureMax': 66.14,
#     u'temperatureMaxTime': 1428868800,
#     u'temperatureMin': 39.82,
#     u'temperatureMinTime': 1428832800,
#     u'time': 1428811200,
#     u'visibility': 10,
#     u'windBearing': 258,
#     u'windSpeed': 7.93}]},
#  u'flags': {u'isd-stations': [u'725090-14739',
#    u'725098-54704',
#    u'744907-14753',
#    u'992420-99999',
#    u'994971-99999'],
#   u'sources': [u'isd'],
#   u'units': u'us'},
#  u'hourly': {u'data': [{u'apparentTemperature': 36.36,
#     u'cloudCover': 0,
#     u'dewPoint': 27.89,
#     u'humidity': 0.55,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1019.36,
#     u'summary': u'Clear',
#     u'temperature': 42.88,
#     u'time': 1428811200,
#     u'visibility': 10,
#     u'windBearing': 283,
#     u'windSpeed': 12.33},
#    {u'apparentTemperature': 35.96,
#     u'cloudCover': 0,
#     u'dewPoint': 27.67,
#     u'humidity': 0.56,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1019.99,
#     u'summary': u'Clear',
#     u'temperature': 42.27,
#     u'time': 1428814800,
#     u'visibility': 10,
#     u'windBearing': 278,
#     u'windSpeed': 11.26},
#    {u'apparentTemperature': 34.21,
#     u'cloudCover': 0,
#     u'dewPoint': 27.52,
#     u'humidity': 0.57,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1020.14,
#     u'summary': u'Clear',
#     u'temperature': 41.41,
#     u'time': 1428818400,
#     u'visibility': 10,
#     u'windBearing': 283,
#     u'windSpeed': 13.2},
#    {u'apparentTemperature': 34.54,
#     u'cloudCover': 0,
#     u'dewPoint': 27.35,
#     u'humidity': 0.58,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1020.36,
#     u'summary': u'Clear',
#     u'temperature': 40.82,
#     u'time': 1428822000,
#     u'visibility': 10,
#     u'windBearing': 281,
#     u'windSpeed': 10.28},
#    {u'apparentTemperature': 33.86,
#     u'cloudCover': 0,
#     u'dewPoint': 27.29,
#     u'humidity': 0.59,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1021,
#     u'summary': u'Clear',
#     u'temperature': 40.61,
#     u'time': 1428825600,
#     u'visibility': 10,
#     u'windBearing': 280,
#     u'windSpeed': 11.34},
#    {u'apparentTemperature': 33.96,
#     u'cloudCover': 0,
#     u'dewPoint': 28.14,
#     u'humidity': 0.63,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1021.67,
#     u'summary': u'Clear',
#     u'temperature': 39.88,
#     u'time': 1428829200,
#     u'visibility': 10,
#     u'windBearing': 275,
#     u'windSpeed': 8.97},
#    {u'apparentTemperature': 34.08,
#     u'cloudCover': 0,
#     u'dewPoint': 28.42,
#     u'humidity': 0.63,
#     u'icon': u'clear-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.64,
#     u'summary': u'Clear',
#     u'temperature': 39.82,
#     u'time': 1428832800,
#     u'visibility': 10,
#     u'windBearing': 266,
#     u'windSpeed': 8.57},
#    {u'apparentTemperature': 35.66,
#     u'cloudCover': 0,
#     u'dewPoint': 29.42,
#     u'humidity': 0.65,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1023.71,
#     u'summary': u'Clear',
#     u'temperature': 40.35,
#     u'time': 1428836400,
#     u'visibility': 10,
#     u'windBearing': 231,
#     u'windSpeed': 6.83},
#    {u'apparentTemperature': 39.03,
#     u'cloudCover': 0,
#     u'dewPoint': 28.51,
#     u'humidity': 0.56,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.46,
#     u'summary': u'Clear',
#     u'temperature': 43.06,
#     u'time': 1428840000,
#     u'visibility': 10,
#     u'windBearing': 247,
#     u'windSpeed': 6.64},
#    {u'apparentTemperature': 42.27,
#     u'cloudCover': 0,
#     u'dewPoint': 27.86,
#     u'humidity': 0.49,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.72,
#     u'summary': u'Clear',
#     u'temperature': 45.9,
#     u'time': 1428843600,
#     u'visibility': 10,
#     u'windBearing': 253,
#     u'windSpeed': 6.96},
#    {u'apparentTemperature': 46.93,
#     u'cloudCover': 0,
#     u'dewPoint': 28.14,
#     u'humidity': 0.43,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.65,
#     u'summary': u'Clear',
#     u'temperature': 49.5,
#     u'time': 1428847200,
#     u'visibility': 10,
#     u'windBearing': 267,
#     u'windSpeed': 6.28},
#    {u'apparentTemperature': 54.42,
#     u'cloudCover': 0,
#     u'dewPoint': 29.27,
#     u'humidity': 0.38,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.59,
#     u'summary': u'Clear',
#     u'temperature': 54.42,
#     u'time': 1428850800,
#     u'visibility': 10,
#     u'windBearing': 260,
#     u'windSpeed': 5.61},
#    {u'apparentTemperature': 56.14,
#     u'cloudCover': 0,
#     u'dewPoint': 28.9,
#     u'humidity': 0.35,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.18,
#     u'summary': u'Clear',
#     u'temperature': 56.14,
#     u'time': 1428854400,
#     u'visibility': 10,
#     u'windBearing': 244,
#     u'windSpeed': 7.43},
#    {u'apparentTemperature': 59.63,
#     u'cloudCover': 0,
#     u'dewPoint': 28.23,
#     u'humidity': 0.3,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1023.69,
#     u'summary': u'Clear',
#     u'temperature': 59.63,
#     u'time': 1428858000,
#     u'visibility': 10,
#     u'windBearing': 266,
#     u'windSpeed': 8.21},
#    {u'apparentTemperature': 61.8,
#     u'cloudCover': 0,
#     u'dewPoint': 29.24,
#     u'humidity': 0.29,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.99,
#     u'summary': u'Clear',
#     u'temperature': 61.8,
#     u'time': 1428861600,
#     u'visibility': 10,
#     u'windBearing': 261,
#     u'windSpeed': 8.07},
#    {u'apparentTemperature': 64.08,
#     u'cloudCover': 0,
#     u'dewPoint': 30.2,
#     u'humidity': 0.28,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.58,
#     u'summary': u'Clear',
#     u'temperature': 64.08,
#     u'time': 1428865200,
#     u'visibility': 10,
#     u'windBearing': 265,
#     u'windSpeed': 11.11},
#    {u'apparentTemperature': 66.14,
#     u'cloudCover': 0,
#     u'dewPoint': 32.51,
#     u'humidity': 0.28,
#     u'icon': u'clear-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.3,
#     u'summary': u'Clear',
#     u'temperature': 66.14,
#     u'time': 1428868800,
#     u'visibility': 10,
#     u'windBearing': 264,
#     u'windSpeed': 7.5},
#    {u'apparentTemperature': 66.1,
#     u'cloudCover': 0.27,
#     u'dewPoint': 30.15,
#     u'humidity': 0.26,
#     u'icon': u'partly-cloudy-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.13,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 66.1,
#     u'time': 1428872400,
#     u'visibility': 10,
#     u'windBearing': 297,
#     u'windSpeed': 7.7},
#    {u'apparentTemperature': 65.55,
#     u'cloudCover': 0.27,
#     u'dewPoint': 30.6,
#     u'humidity': 0.27,
#     u'icon': u'partly-cloudy-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.38,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 65.55,
#     u'time': 1428876000,
#     u'visibility': 10,
#     u'windBearing': 292,
#     u'windSpeed': 7},
#    {u'apparentTemperature': 64.87,
#     u'cloudCover': 0.27,
#     u'dewPoint': 30.57,
#     u'humidity': 0.28,
#     u'icon': u'partly-cloudy-day',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1022.93,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 64.87,
#     u'time': 1428879600,
#     u'visibility': 10,
#     u'windBearing': 267,
#     u'windSpeed': 6.47},
#    {u'apparentTemperature': 59.22,
#     u'cloudCover': 0.27,
#     u'dewPoint': 37.41,
#     u'humidity': 0.44,
#     u'icon': u'partly-cloudy-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1023.73,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 59.22,
#     u'time': 1428883200,
#     u'visibility': 10,
#     u'windBearing': 175,
#     u'windSpeed': 13.84},
#    {u'apparentTemperature': 55.41,
#     u'cloudCover': 0.27,
#     u'dewPoint': 37.27,
#     u'humidity': 0.5,
#     u'icon': u'partly-cloudy-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1024.95,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 55.41,
#     u'time': 1428886800,
#     u'visibility': 10,
#     u'windBearing': 199,
#     u'windSpeed': 8.54},
#    {u'apparentTemperature': 54.76,
#     u'cloudCover': 0.27,
#     u'dewPoint': 35.34,
#     u'humidity': 0.48,
#     u'icon': u'partly-cloudy-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1025.24,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 54.76,
#     u'time': 1428890400,
#     u'visibility': 10,
#     u'windBearing': 219,
#     u'windSpeed': 13.06},
#    {u'apparentTemperature': 54.55,
#     u'cloudCover': 0.27,
#     u'dewPoint': 34.3,
#     u'humidity': 0.46,
#     u'icon': u'partly-cloudy-night',
#     u'precipIntensity': 0,
#     u'precipProbability': 0,
#     u'pressure': 1025.56,
#     u'summary': u'Partly Cloudy',
#     u'temperature': 54.55,
#     u'time': 1428894000,
#     u'visibility': 10,
#     u'windBearing': 229,
#     u'windSpeed': 13.7}],
#   u'icon': u'partly-cloudy-night',
#   u'summary': u'Partly cloudy starting in the evening.'},
#  u'latitude': 42.33196,
#  u'longitude': -71.020173,
#  u'offset': -4,
#  u'timezone': u'America/New_York'}

# %%
for city in cities:
    utc_now = datetime.datetime.now() - datetime.timedelta(days=30)
    url = "https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/" + cities[city] + "," + utc_now.strftime('%s')
    print url
# Out:
# https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/42.331960,-71.020173,1428881556
# https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/33.762909,-84.422675,1428881556
# https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/41.478462,-81.679435,1428881556
# https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/30.303936,-97.754355,1428881556
# https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/41.837551,-87.681844,1428881556

# %%
for ciudad in cities:
    start_date = datetime.datetime.now() - datetime.timedelta(days=30)
    time = start_date
    for i in range(30):
        url = "https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/" + cities[ciudad] + "," + time.strftime('%s')
        r = requests.get(url)

        #a prepared SQL statement we're going to execute over and over again
        sql = "INSERT INTO weather (city,time,temp) VALUES (?,?,?)"

        city = r.json()['daily']['data'][0]
        #id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location)
        cur.execute(sql,(ciudad,city['time'],city['apparentTemperatureMax']))
        time += datetime.timedelta(days=1)

# %%
df = pd.read_sql_query("SELECT * FROM weather ORDER BY city",con,index_col='time')
df.head()
# Out:
#                city   temp
# time
# 1428811200  Atlanta  69.61
# 1428897600  Atlanta  72.95
# 1428984000  Atlanta  82.12
# 1429070400  Atlanta  74.05
# 1429156800  Atlanta  56.16

# %%
df.groupby('city').mean()
# Out:
#                 temp
# city
# Atlanta    75.442333
# Austin     81.939333
# Boston     61.149333
# Chicago    59.845333
# Cleveland  61.175000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.groupby('city').hist()
# Out:
# city
# Atlanta      [[Axes(0.125,0.125;0.775x0.775)]]
# Austin       [[Axes(0.125,0.125;0.775x0.775)]]
# Boston       [[Axes(0.125,0.125;0.775x0.775)]]
# Chicago      [[Axes(0.125,0.125;0.775x0.775)]]
# Cleveland    [[Axes(0.125,0.125;0.775x0.775)]]
# dtype: object

# %%
df.groupby('city').min()
# Out:
#             temp
# city
# Atlanta    56.16
# Austin     67.28
# Boston     42.64
# Chicago    37.98
# Cleveland  29.32

# %%
df.groupby('city').max()
# Out:
#             temp
# city
# Atlanta    91.02
# Austin     91.47
# Boston     84.18
# Chicago    80.81
# Cleveland  86.97

# %%
df[df['city'].isin(['Atlanta'])]
# Out:
#                city   temp
# time
# 1428811200  Atlanta  69.61
# 1428897600  Atlanta  72.95
# 1428984000  Atlanta  82.12
# 1429070400  Atlanta  74.05
# 1429156800  Atlanta  56.16
# 1429243200  Atlanta  62.47
# 1429329600  Atlanta  72.00
# 1429416000  Atlanta  70.72
# 1429502400  Atlanta  75.62
# 1429588800  Atlanta  69.66
# 1429675200  Atlanta  77.34
# 1429761600  Atlanta  66.20
# 1429848000  Atlanta  75.70
# 1429934400  Atlanta  77.40
# 1430020800  Atlanta  81.46
# 1430107200  Atlanta  69.61
# 1430193600  Atlanta  71.81
# 1430280000  Atlanta  61.95
# 1430366400  Atlanta  72.22
# 1430452800  Atlanta  69.05
# 1430539200  Atlanta  75.25
# 1430625600  Atlanta  79.35
# 1430712000  Atlanta  80.01
# 1430798400  Atlanta  80.11
# 1430884800  Atlanta  81.47
# 1430971200  Atlanta  84.29
# 1431057600  Atlanta  87.34
# 1431144000  Atlanta  87.54
# 1431230400  Atlanta  88.79
# 1431316800  Atlanta  91.02

# %%
for key, grp in df.groupby(['city']):
  print grp,key
# Out:
#                city   temp
# time
# 1428811200  Atlanta  69.61
# 1428897600  Atlanta  72.95
# 1428984000  Atlanta  82.12
# 1429070400  Atlanta  74.05
# 1429156800  Atlanta  56.16
# 1429243200  Atlanta  62.47
# 1429329600  Atlanta  72.00
# 1429416000  Atlanta  70.72
# 1429502400  Atlanta  75.62
# 1429588800  Atlanta  69.66
# 1429675200  Atlanta  77.34
# 1429761600  Atlanta  66.20
# 1429848000  Atlanta  75.70
# 1429934400  Atlanta  77.40
# 1430020800  Atlanta  81.46
# 1430107200  Atlanta  69.61
# 1430193600  Atlanta  71.81
# 1430280000  Atlanta  61.95
# 1430366400  Atlanta  72.22
# 1430452800  Atlanta  69.05
# 1430539200  Atlanta  75.25
# 1430625600  Atlanta  79.35
# 1430712000  Atlanta  80.01
# 1430798400  Atlanta  80.11
# 1430884800  Atlanta  81.47
# 1430971200  Atlanta  84.29
# 1431057600  Atlanta  87.34
# 1431144000  Atlanta  87.54
# 1431230400  Atlanta  88.79
# 1431316800  Atlanta  91.02 Atlanta
#               city   temp
# time
# 1428814800  Austin  84.20
# 1428901200  Austin  84.95
# 1428987600  Austin  75.21
# 1429074000  Austin  80.65
# 1429160400  Austin  79.24
# 1429246800  Austin  74.55
# 1429333200  Austin  76.68
# 1429419600  Austin  84.96
# 1429506000  Austin  72.46
# 1429592400  Austin  80.57
# 1429678800  Austin  78.54
# 1429765200  Austin  88.24
# 1429851600  Austin  88.83
# 1429938000  Austin  88.14
# 1430024400  Austin  88.51
# 1430110800  Austin  82.78
# 1430197200  Austin  67.28
# 1430283600  Austin  74.86
# 1430370000  Austin  79.53
# 1430456400  Austin  80.77
# 1430542800  Austin  80.49
# 1430629200  Austin  82.14
# 1430715600  Austin  83.46
# 1430802000  Austin  83.20
# 1430888400  Austin  89.18
# 1430974800  Austin  87.18
# 1431061200  Austin  84.29
# 1431147600  Austin  89.55
# 1431234000  Austin  91.47
# 1431320400  Austin  76.27 Austin
#               city   temp
# time
# 1428811200  Boston  66.14
# 1428897600  Boston  68.34
# 1428984000  Boston  64.56
# 1429070400  Boston  64.18
# 1429156800  Boston  57.74
# 1429243200  Boston  62.99
# 1429329600  Boston  58.95
# 1429416000  Boston  42.64
# 1429502400  Boston  52.02
# 1429588800  Boston  63.40
# 1429675200  Boston  66.14
# 1429761600  Boston  50.86
# 1429848000  Boston  43.91
# 1429934400  Boston  54.38
# 1430020800  Boston  54.87
# 1430107200  Boston  55.65
# 1430193600  Boston  61.28
# 1430280000  Boston  51.92
# 1430366400  Boston  53.63
# 1430452800  Boston  44.64
# 1430539200  Boston  52.24
# 1430625600  Boston  63.66
# 1430712000  Boston  78.26
# 1430798400  Boston  69.43
# 1430884800  Boston  68.35
# 1430971200  Boston  74.38
# 1431057600  Boston  65.20
# 1431144000  Boston  68.87
# 1431230400  Boston  84.18
# 1431316800  Boston  71.67 Boston
#                city   temp
# time
# 1428814800  Chicago  67.84
# 1428901200  Chicago  66.56
# 1428987600  Chicago  59.59
# 1429074000  Chicago  59.08
# 1429160400  Chicago  56.30
# 1429246800  Chicago  73.73
# 1429333200  Chicago  64.65
# 1429419600  Chicago  62.13
# 1429506000  Chicago  54.34
# 1429592400  Chicago  55.30
# 1429678800  Chicago  39.58
# 1429765200  Chicago  47.02
# 1429851600  Chicago  54.80
# 1429938000  Chicago  37.98
# 1430024400  Chicago  51.03
# 1430110800  Chicago  51.46
# 1430197200  Chicago  52.68
# 1430283600  Chicago  55.22
# 1430370000  Chicago  40.37
# 1430456400  Chicago  58.47
# 1430542800  Chicago  71.29
# 1430629200  Chicago  76.38
# 1430715600  Chicago  70.61
# 1430802000  Chicago  54.31
# 1430888400  Chicago  71.86
# 1430974800  Chicago  80.81
# 1431061200  Chicago  78.57
# 1431147600  Chicago  61.97
# 1431234000  Chicago  54.29
# 1431320400  Chicago  67.14 Chicago
#                  city   temp
# time
# 1428811200  Cleveland  58.92
# 1428897600  Cleveland  79.22
# 1428984000  Cleveland  56.56
# 1429070400  Cleveland  52.42
# 1429156800  Cleveland  59.97
# 1429243200  Cleveland  58.49
# 1429329600  Cleveland  63.72
# 1429416000  Cleveland  74.02
# 1429502400  Cleveland  66.45
# 1429588800  Cleveland  56.73
# 1429675200  Cleveland  41.39
# 1429761600  Cleveland  29.32
# 1429848000  Cleveland  43.91
# 1429934400  Cleveland  39.01
# 1430020800  Cleveland  43.55
# 1430107200  Cleveland  38.10
# 1430193600  Cleveland  51.52
# 1430280000  Cleveland  57.88
# 1430366400  Cleveland  44.55
# 1430452800  Cleveland  60.48
# 1430539200  Cleveland  67.72
# 1430625600  Cleveland  72.44
# 1430712000  Cleveland  77.03
# 1430798400  Cleveland  63.05
# 1430884800  Cleveland  65.11
# 1430971200  Cleveland  75.26
# 1431057600  Cleveland  82.68
# 1431144000  Cleveland  85.69
# 1431230400  Cleveland  86.97
# 1431316800  Cleveland  83.09 Cleveland

# %%
#df.groupby('city').plot(figsize=(10,4));
#plt.show()
y = df[df['city'].isin(['Atlanta'])]
x = y['temp']
z = df[df['city'].isin(['Boston'])]
a = z['temp']

#for key, grp in df.groupby(['city']):
  #plt.plot(grp['Atlanta'], label=key)
plt.plot(x)
plt.plot(a)
plt.legend(['Atlanta', 'Boston'], loc='upper left')    
plt.show()
