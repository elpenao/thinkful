# %%
cities = { "Atlanta": '33.762909,-84.422675',
            "Austin": '30.303936,-97.754355',
            "Boston": '42.331960,-71.020173',
            "Chicago": '41.837551,-87.681844',
            "Cleveland": '41.478462,-81.679435'
        }

# %%
import datetime

# %%
import requests

# %%
dt = datetime.datetime.utcnow()

# %%
dt
# Out:
# datetime.datetime(2015, 5, 10, 21, 42, 50, 854667)

# %%
now     = datetime.datetime.now()
utc_now = datetime.datetime.utcnow()

ts      = now.strftime("%s")
utc_ts  = utc_now.strftime("%s")

print ts
print utc_ts
# Out:
# 1431294190
# 1431308590

# %%
https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/33.762909,-84.422675,1431308590
# Out:
#   File "<ipython-input-14-fb641a080d84>", line 1
#     https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/33.762909,-84.422675,1431308590
#          ^
# SyntaxError: invalid syntax

# %%
r = requests.get('https://api.forecast.io/forecast/113919b256fd6283e5236aee1b03afad/33.762909,-84.422675,1431308590')

# %%
r.json()
# Out:
# {u'currently': {u'apparentTemperature': 79.02,
#   u'cloudCover': 0.48,
#   u'dewPoint': 64.15,
#   u'humidity': 0.6,
#   u'icon': u'partly-cloudy-night',
#   u'ozone': 316.34,
#   u'precipIntensity': 0,
#   u'precipProbability': 0,
#   u'pressure': 1017.67,
#   u'summary': u'Partly Cloudy',
#   u'temperature': 79.02,
#   u'time': 1431308590,
#   u'visibility': 10,
#   u'windBearing': 226,
#   u'windSpeed': 2.03},
#  u'daily': {u'data': [{u'apparentTemperatureMax': 88.55,
#     u'apparentTemperatureMaxTime': 1431284400,
#     u'apparentTemperatureMin': 65.09,
#     u'apparentTemperatureMinTime': 1431255600,
#     u'cloudCover': 0.44,
#     u'dewPoint': 62.9,
#     u'humidity': 0.65,
#     u'icon': u'rain',
#     u'moonPhase': 0.72,
#     u'ozone': 312.33,
#     u'precipIntensity': 0.0035,
#     u'precipIntensityMax': 0.0292,
#     u'precipIntensityMaxTime': 1431291600,
#     u'precipProbability': 0.95,
#     u'precipType': u'rain',
#     u'pressure': 1018.78,
# ...
